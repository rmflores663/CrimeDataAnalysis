# %%
import numpy as numpy
import pandas as pd
from geopy.geocoders import Nominatim

crimedata = pd.read_excel("savedGeneratedCrimeData.xlsx")

# %%
def get_zipcode(latitude, longitude):
    geolocator = Nominatim(user_agent="zipcode_finder")
    location = geolocator.reverse((latitude, longitude), addressdetails=True)
    if 'postcode' in location.raw['address']:
        return location.raw['address']['postcode']
    else:
        return "Zipcode not found"

# %%
latitudeData = crimedata["Latitude"]
longitudeData = crimedata["Longitude"]
crimeType = crimedata["Primary Type"]
zipcodes = crimedata['Zipcode']
crimedata.head(100)
# Out:
#           ID Case Number                Block         Primary Type  \
# 0   12712384    JF250460  106 S STATE LINE RD  MOTOR VEHICLE THEFT
# 1   12913075    JF498893  106 S STATE LINE RD              BATTERY
# 2   12715041    JF261663  106 S STATE LINE RD    CRIMINAL TRESPASS
# 3   12722472    JF270707  106 S STATE LINE RD        OTHER OFFENSE
# 4   12876779    JF454503  106 S STATE LINE RD        OTHER OFFENSE
# ..       ...         ...                  ...                  ...
# 95  12756977    JF312639       040 E 134TH ST              ASSAULT
# 96  12697602    JF240617       040 E 134TH ST              ASSAULT
# 97  12668240    JF205066       040 E 134TH ST              ASSAULT
# 98  12825852    JF394386       040 E 134TH ST              ASSAULT
# 99  12908493    JF493227       040 E 134TH ST              ASSAULT
#
#                Location Description   Latitude  Longitude  \
# 0                            STREET  41.701771 -87.524532
# ...

# %%
for x in range(1000):
    crimedata.at[x, 'Zipcode'] = get_zipcode(latitudeData[x], longitudeData[x])
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1376             try:
# ...

# %%
crimedata.to_excel('savedGeneratedCrimeData.xlsx')

# %%
duplicate = crimedata[crimedata.duplicated(['Zipcode', 'Primary Type'])]
duplicate
# Out:
#         Unnamed: 0        ID Case Number                Block  \
# 4                4  12876779    JF454503  106 S STATE LINE RD
# 5                5  12839453    JF410809  107 S STATE LINE RD
# 7                7  12681872    JF221218  109 S STATE LINE RD
# 8                8  12787035    JF348398  111 S STATE LINE RD
# 9                9  12790533    JF351414  111 S STATE LINE RD
# ...            ...       ...         ...                  ...
# 234894      234894  12761006    JF317384       007 W OHARE ST
# 234895      234895  12879864    JF459018       007 W OHARE ST
# 234896      234896  12869573    JF446764       007 W OHARE ST
# 234897      234897  12623847    JF151637           W OHARE ST
# 234898      234898  12622711    JF150203           W OHARE ST
#
#                Primary Type                            Location Description  \
# 4             OTHER OFFENSE                                       APARTMENT
# ...

# %%
countOfCrimes = crimedata.pivot_table(index =['Zipcode', 'Primary Type'], aggfunc = 'size')
countOfCrimes #.to_excel('CountOfCrimes.xlsx')
# Out:
# Zipcode  Primary Type
# 46394.0  ASSAULT                        3
#          BATTERY                       11
#          BURGLARY                       2
#          CRIMINAL DAMAGE               11
#          DECEPTIVE PRACTICE             6
#          HOMICIDE                       1
#          MOTOR VEHICLE THEFT            7
#          OFFENSE INVOLVING CHILDREN     1
#          OTHER OFFENSE                  1
#          ROBBERY                        1
#          THEFT                          4
#          WEAPONS VIOLATION              3
# 60617.0  ASSAULT                       27
#          BATTERY                       60
#          BURGLARY                       7
#          CRIMINAL DAMAGE               37
#          CRIMINAL SEXUAL ASSAULT        1
#          CRIMINAL TRESPASS              5
#          DECEPTIVE PRACTICE            13
#          HOMICIDE                       1
#          MOTOR VEHICLE THEFT           21
#          NARCOTICS                      3
# ...

# %%
#x axis for bar graph:
#Robbery, Homicide, Criminal Sexual Assault, Assault, Motor Vehicle Theft, Burglary
print(countOfCrimes['Zipcode'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Float64Engine._check_type()
#
# KeyError: 'Zipcode'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7696\4166631622.py in <module>
#       1 #x axis for bar graph:
# ...

# %%
countOfCrimes
# Out:
# Zipcode  Primary Type
# 46394.0  ASSAULT                        3
#          BATTERY                       11
#          BURGLARY                       2
#          CRIMINAL DAMAGE               11
#          DECEPTIVE PRACTICE             6
#          HOMICIDE                       1
#          MOTOR VEHICLE THEFT            7
#          OFFENSE INVOLVING CHILDREN     1
#          OTHER OFFENSE                  1
#          ROBBERY                        1
#          THEFT                          4
#          WEAPONS VIOLATION              3
# 60617.0  ASSAULT                       27
#          BATTERY                       60
#          BURGLARY                       7
#          CRIMINAL DAMAGE               37
#          CRIMINAL SEXUAL ASSAULT        1
#          CRIMINAL TRESPASS              5
#          DECEPTIVE PRACTICE            13
#          HOMICIDE                       1
#          MOTOR VEHICLE THEFT           21
#          NARCOTICS                      3
# ...

# %%
countOfCrimes.loc["46394":"60617"].plot.bar()
# Out:
# <AxesSubplot:xlabel='Zipcode,Primary Type'>

# %%
labels = ["ASSAULT", "BURGLARY", "CRIMINAL SEXUAL ASSAULT", "HOMICIDE", "MOTOR VEHICLE THEFT", "ROBBERY"]

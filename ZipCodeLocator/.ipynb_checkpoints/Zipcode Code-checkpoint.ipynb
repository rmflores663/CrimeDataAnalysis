# %% [markdown]
# # Importing

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("CountOfCrimes.xlsx")

# %%
df
# Out:
#     Zipcode                Primary Type   0
# 0   46394.0                     ASSAULT   3
# 1       NaN                     BATTERY  11
# 2       NaN                    BURGLARY   2
# 3       NaN             CRIMINAL DAMAGE  11
# 4       NaN          DECEPTIVE PRACTICE   6
# 5       NaN                    HOMICIDE   1
# 6       NaN         MOTOR VEHICLE THEFT   7
# 7       NaN  OFFENSE INVOLVING CHILDREN   1
# 8       NaN               OTHER OFFENSE   1
# 9       NaN                     ROBBERY   1
# 10      NaN                       THEFT   4
# 11      NaN           WEAPONS VIOLATION   3
# 12  60617.0                     ASSAULT  27
# 13      NaN                     BATTERY  60
# 14      NaN                    BURGLARY   7
# 15      NaN             CRIMINAL DAMAGE  37
# 16      NaN     CRIMINAL SEXUAL ASSAULT   1
# 17      NaN           CRIMINAL TRESPASS   5
# 18      NaN          DECEPTIVE PRACTICE  13
# 19      NaN                    HOMICIDE   1
# 20      NaN         MOTOR VEHICLE THEFT  21
# 21      NaN                   NARCOTICS   3
# 22      NaN  OFFENSE INVOLVING CHILDREN   2
# 23      NaN               OTHER OFFENSE  28
# 24      NaN                     ROBBERY  11
# 25      NaN                 SEX OFFENSE   2
# 26      NaN                       THEFT  58
# 27      NaN           WEAPONS VIOLATION   6
# 28  60633.0                     ASSAULT  15
# 29      NaN                     BATTERY  26
# 30      NaN                    BURGLARY   2
# 31      NaN             CRIMINAL DAMAGE  14
# 32      NaN     CRIMINAL SEXUAL ASSAULT   1
# 33      NaN           CRIMINAL TRESPASS   1
# 34      NaN          DECEPTIVE PRACTICE   7
# 35      NaN                  KIDNAPPING   1
# 36      NaN         MOTOR VEHICLE THEFT   7
# 37      NaN  OFFENSE INVOLVING CHILDREN   2
# 38      NaN               OTHER OFFENSE  11
# 39      NaN                     ROBBERY   1
# 40      NaN                       THEFT  13
# 41      NaN           WEAPONS VIOLATION   1

# %% [markdown]
# # Cleaning

# %%
existing_col_names = list(df.columns)
new_col_names = ["Zipcode", "Primary Type", "Value"]
change_names = dict(zip(existing_col_names, new_col_names))
change_names
# Out:
# {'Zipcode': 'Zipcode', 'Primary Type': 'Primary Type', 0: 'Value'}

# %%
df.rename(columns=change_names, inplace=True)
df.head()
# Out:
#    Zipcode        Primary Type  Value
# 0  46394.0             ASSAULT      3
# 1      NaN             BATTERY     11
# 2      NaN            BURGLARY      2
# 3      NaN     CRIMINAL DAMAGE     11
# 4      NaN  DECEPTIVE PRACTICE      6

# %%
df1 = df.fillna(method='ffill')
df1
# Out:
#     Zipcode                Primary Type  Value
# 0   46394.0                     ASSAULT      3
# 1   46394.0                     BATTERY     11
# 2   46394.0                    BURGLARY      2
# 3   46394.0             CRIMINAL DAMAGE     11
# 4   46394.0          DECEPTIVE PRACTICE      6
# 5   46394.0                    HOMICIDE      1
# 6   46394.0         MOTOR VEHICLE THEFT      7
# 7   46394.0  OFFENSE INVOLVING CHILDREN      1
# 8   46394.0               OTHER OFFENSE      1
# 9   46394.0                     ROBBERY      1
# 10  46394.0                       THEFT      4
# 11  46394.0           WEAPONS VIOLATION      3
# 12  60617.0                     ASSAULT     27
# 13  60617.0                     BATTERY     60
# 14  60617.0                    BURGLARY      7
# 15  60617.0             CRIMINAL DAMAGE     37
# 16  60617.0     CRIMINAL SEXUAL ASSAULT      1
# 17  60617.0           CRIMINAL TRESPASS      5
# 18  60617.0          DECEPTIVE PRACTICE     13
# 19  60617.0                    HOMICIDE      1
# 20  60617.0         MOTOR VEHICLE THEFT     21
# 21  60617.0                   NARCOTICS      3
# 22  60617.0  OFFENSE INVOLVING CHILDREN      2
# 23  60617.0               OTHER OFFENSE     28
# 24  60617.0                     ROBBERY     11
# 25  60617.0                 SEX OFFENSE      2
# 26  60617.0                       THEFT     58
# 27  60617.0           WEAPONS VIOLATION      6
# 28  60633.0                     ASSAULT     15
# 29  60633.0                     BATTERY     26
# 30  60633.0                    BURGLARY      2
# 31  60633.0             CRIMINAL DAMAGE     14
# 32  60633.0     CRIMINAL SEXUAL ASSAULT      1
# 33  60633.0           CRIMINAL TRESPASS      1
# 34  60633.0          DECEPTIVE PRACTICE      7
# 35  60633.0                  KIDNAPPING      1
# 36  60633.0         MOTOR VEHICLE THEFT      7
# 37  60633.0  OFFENSE INVOLVING CHILDREN      2
# 38  60633.0               OTHER OFFENSE     11
# 39  60633.0                     ROBBERY      1
# 40  60633.0                       THEFT     13
# 41  60633.0           WEAPONS VIOLATION      1

# %%
req_values = ["ASSAULT", "BURGLARY", "HOMICIDE", "MOTOR VEHICLE THEFT", "CRIMINAL SEXUAL ASSAULT", "THEFT"]

# %%
filtered_df = df1[df1['Primary Type'].isin(req_values)]
filtered_df
# Out:
#     Zipcode             Primary Type  Value
# 0   46394.0                  ASSAULT      3
# 2   46394.0                 BURGLARY      2
# 5   46394.0                 HOMICIDE      1
# 6   46394.0      MOTOR VEHICLE THEFT      7
# 10  46394.0                    THEFT      4
# 12  60617.0                  ASSAULT     27
# 14  60617.0                 BURGLARY      7
# 16  60617.0  CRIMINAL SEXUAL ASSAULT      1
# 19  60617.0                 HOMICIDE      1
# 20  60617.0      MOTOR VEHICLE THEFT     21
# 26  60617.0                    THEFT     58
# 28  60633.0                  ASSAULT     15
# 30  60633.0                 BURGLARY      2
# 32  60633.0  CRIMINAL SEXUAL ASSAULT      1
# 36  60633.0      MOTOR VEHICLE THEFT      7
# 40  60633.0                    THEFT     13

# %%
unique_zipcodes = filtered_df['Zipcode'].unique()
len(unique_zipcodes)
# Out:
# 3

# %%
new_rows = pd.DataFrame([])

# %%
for i in range(len(unique_zipcodes)):
    vals = set(filtered_df[filtered_df["Zipcode"]==unique_zipcodes[i]]["Primary Type"])
    missing_vals = set(req_values) - vals
    missing_vals = list(missing_vals)
    for j in range(len(missing_vals)):
        new_row = {'Zipcode': unique_zipcodes[i], 'Primary Type': missing_vals[j], 'Value': 0}
        print(new_row)
        new_rows = pd.concat([new_rows, pd.DataFrame([new_row])], ignore_index = True)
# Out:
# {'Zipcode': 46394.0, 'Primary Type': 'CRIMINAL SEXUAL ASSAULT', 'Value': 0}
# {'Zipcode': 60633.0, 'Primary Type': 'HOMICIDE', 'Value': 0}

# %%
df2 = pd.concat([filtered_df, new_rows], ignore_index=True)
df2
# Out:
#     Zipcode             Primary Type  Value
# 0   46394.0                  ASSAULT      3
# 1   46394.0                 BURGLARY      2
# 2   46394.0                 HOMICIDE      1
# 3   46394.0      MOTOR VEHICLE THEFT      7
# 4   46394.0                    THEFT      4
# 5   60617.0                  ASSAULT     27
# 6   60617.0                 BURGLARY      7
# 7   60617.0  CRIMINAL SEXUAL ASSAULT      1
# 8   60617.0                 HOMICIDE      1
# 9   60617.0      MOTOR VEHICLE THEFT     21
# 10  60617.0                    THEFT     58
# 11  60633.0                  ASSAULT     15
# 12  60633.0                 BURGLARY      2
# 13  60633.0  CRIMINAL SEXUAL ASSAULT      1
# 14  60633.0      MOTOR VEHICLE THEFT      7
# 15  60633.0                    THEFT     13
# 16  46394.0  CRIMINAL SEXUAL ASSAULT      0
# 17  60633.0                 HOMICIDE      0

# %%
vals = set(filtered_df[filtered_df["Zipcode"]==unique_zipcodes[0]]["Primary Type"])
vals
# Out:
# {'ASSAULT', 'BURGLARY', 'HOMICIDE', 'MOTOR VEHICLE THEFT', 'THEFT'}

# %%
missing_vals = set(req_values) - vals
missing_vals = list(missing_vals)
missing_vals
# Out:
# ['CRIMINAL SEXUAL ASSAULT']

# %%
new_row = {'Zipcode': unique_zipcodes[0], 'Primary Type': missing_vals[0], 'Value': 0}

# %%
df2 = pd.concat([filtered_df, pd.DataFrame([new_row])], ignore_index=True)
df2
# Out:
#     Zipcode             Primary Type  Value
# 0   46394.0                  ASSAULT      3
# 1   46394.0                 BURGLARY      2
# 2   46394.0                 HOMICIDE      1
# 3   46394.0      MOTOR VEHICLE THEFT      7
# 4   46394.0                    THEFT      4
# 5   60617.0                  ASSAULT     27
# 6   60617.0                 BURGLARY      7
# 7   60617.0  CRIMINAL SEXUAL ASSAULT      1
# 8   60617.0                 HOMICIDE      1
# 9   60617.0      MOTOR VEHICLE THEFT     21
# 10  60617.0                    THEFT     58
# 11  60633.0                  ASSAULT     15
# 12  60633.0                 BURGLARY      2
# 13  60633.0  CRIMINAL SEXUAL ASSAULT      1
# 14  60633.0      MOTOR VEHICLE THEFT      7
# 15  60633.0                    THEFT     13
# 16  46394.0  CRIMINAL SEXUAL ASSAULT      0

# %%
df3 = df2[df2["Zipcode"] == 46394.0]
df3
# Out:
#     Zipcode             Primary Type  Value
# 0   46394.0                  ASSAULT      3
# 1   46394.0                 BURGLARY      2
# 2   46394.0                 HOMICIDE      1
# 3   46394.0      MOTOR VEHICLE THEFT      7
# 4   46394.0                    THEFT      4
# 16  46394.0  CRIMINAL SEXUAL ASSAULT      0

# %% [markdown]
# # Plotting

# %%
for i in range(len(unique_zipcodes)):
    df4 = df2[df2['Zipcode'] == unique_zipcodes[i]]
    x = list(df4["Primary Type"])
    y = list(df4["Value"])
    plt.bar(x, y)
    plt.xticks(rotation=40)
    plt.title(unique_zipcodes[i])
    plt.show()

# %%
x = list(df3["Primary Type"])
x
# Out:
# ['ASSAULT',
#  'BURGLARY',
#  'HOMICIDE',
#  'MOTOR VEHICLE THEFT',
#  'THEFT',
#  'CRIMINAL SEXUAL ASSAULT']

# %%
y = list(df3["Value"])
y
# Out:
# [3, 2, 1, 7, 4, 0]

# %%
plt.plot(x, y)
plt.xticks(rotation=40)
plt.show()
